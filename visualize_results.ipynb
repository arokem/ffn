# %%
import dask.array as da

# %%
import tifffile as tiff

# %%
im = tiff.imread('./third_party/DaceyLab/z_10.84_to_z_3609_72-grayscale2-002.tif')

# %%
im.shape
# Out:
# (333, 2518, 4084)

# %%
da.from_array(im, chunks=())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-edd1adebfe6c> in <module>
# ----> 1 da.from_array(im, chunks=())
#
# ~/.local/lib/python3.5/site-packages/dask/array/core.py in from_array(x, chunks, name, lock, asarray, fancy, getitem)
#    2200         x = np.array(x)
#    2201
# -> 2202     chunks = normalize_chunks(chunks, x.shape, dtype=x.dtype)
#    2203     if name in (None, True):
#    2204         token = tokenize(x, chunks)
#
# ~/.local/lib/python3.5/site-packages/dask/array/core.py in normalize_chunks(chunks, shape, limit, dtype, previous_chunks)
#    1985         raise ValueError(
#    1986             "Chunks and shape must be of the same length/dimension. "
# -> 1987             "Got chunks=%s, shape=%s" % (chunks, shape))
#    1988     if -1 in chunks:
#    1989         chunks = tuple(s if c == -1 else c for c, s in zip(chunks, shape))
#
# ...

# %%
im.shape
# Out:
# (333, 2518, 4084)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
filename = 'results/dacey/target_0_250.npz'
f = np.load(filename)

# %%
f.files
# Out:
# ['counters', 'overlaps', 'request', 'origins', 'segmentation']

# %%
im.shape
# Out:
# (333, 2518, 4084)

# %%
seg = f['segmentation']
seg.shape
# Out:
# (333, 250, 250)

# %%
fig, ax = plt.subplots(1)
ax.matshow(im[100, :250, :250], cmap='gray')
ax.matshow(seg[100], cmap='tab20', alpha=0.5)

# %%
im.std()
# Out:
# 142.91683915071118

# %%
im.
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-21-59da7e0b2185> in <module>()
# ----> 1 im.std()
#
# ~/.local/lib/python3.5/site-packages/numpy/core/_methods.py in _std(a, axis, dtype, out, ddof, keepdims)
#     138 def _std(a, axis=None, dtype=None, out=None, ddof=0, keepdims=False):
#     139     ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# --> 140                keepdims=keepdims)
#     141
#     142     if isinstance(ret, mu.ndarray):
#
# ~/.local/lib/python3.5/site-packages/numpy/core/_methods.py in _var(a, axis, dtype, out, ddof, keepdims)
#     115     # Note that x may not be inexact and that we need it to be an array,
#     116     # not a scalar.
# --> 117     x = asanyarray(arr - arrmean)
#     118     if issubclass(arr.dtype.type, nt.complexfloating):
#     119         x = um.multiply(x, um.conjugate(x), out=x).real
#
# MemoryError:

# %%
plt.matshow(im[171, 1774:2000, 1808:2000], cmap='gray')

# %%
im_rgb = tiff.imread('./third_party/dacey/z_10.84_to_z_3609_72-RGB2-003.tif')
